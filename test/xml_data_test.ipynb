# %%
import xml_data
import pretty_midi
# test_xml = 'examples/bps8-2/xml.xml'
# test_xml = 'examples/ballade1/musicxml_cleaned.musicxml'
# test_xml = '/projects/perform_piano/musicXML_parser/mxp/testdata/chopinBallade1/xml.xml'
# test_xml = "/dataset/chopin_cleaned/Chopin_Etude_op_25/11/musicxml_cleaned.musicxml"
test_xml = "/dataset/chopin_cleaned/Chopin_Ballade/3/musicxml_cleaned.musicxml"

# %%
xml_sequence = xml_data.XmlNoteSequence(test_xml)
print(vars(xml_sequence).keys())
# Out:
# dict_keys(['xml_path', 'xml_doc', 'notes', 'rests', 'meta', 'total_length', 'num_notes'])
# /projects/perform_piano/perform_piano/xml_data.py:384: RuntimeWarning: Any note found to match tied_stop. note: 767
#   warnings.warn("Any note found to match tied_stop. note: {:d}".format(i), RuntimeWarning)
# /projects/perform_piano/perform_piano/xml_data.py:384: RuntimeWarning: Any note found to match tied_stop. note: 768
#   warnings.warn("Any note found to match tied_stop. note: {:d}".format(i), RuntimeWarning)

# %%
print(xml_sequence.total_length)
print(xml_sequence.xml_path)
print(xml_sequence.num_notes)
# Out:
# 115680
# /dataset/chopin_cleaned/Chopin_Ballade/3/musicxml_cleaned.musicxml
# 4473

# %%
xml_sequence.save_to_midi(xml_sequence.notes, ('xml.mid'))

# %%
for note in xml_sequence.notes:
  if note.note_duration.is_grace_note:
    print(note.note_duration.__dict__)
# Out:
# {'duration': 0, 'midi_ticks': 0.0, 'seconds': 0.0, 'time_position': 32.5625, 'xml_position': 10480, 'dots': 0, '_type': 'eighth', 'tuplet_ratio': Fraction(1, 1), 'is_grace_note': True, 'state': <musicXML_parser.mxp.main.MusicXMLParserState object at 0x7fe14d450d30>, 'after_grace_note': True, 'grace_order': -3, 'num_grace': 3}
# {'duration': 0, 'midi_ticks': 0.0, 'seconds': 0.0, 'time_position': 32.625, 'xml_position': 10480, 'dots': 0, '_type': 'eighth', 'tuplet_ratio': Fraction(1, 1), 'is_grace_note': True, 'state': <musicXML_parser.mxp.main.MusicXMLParserState object at 0x7fe14d450d30>, 'after_grace_note': True, 'grace_order': -2, 'num_grace': 3}
# {'duration': 0, 'midi_ticks': 0.0, 'seconds': 0.0, 'time_position': 32.6875, 'xml_position': 10480, 'dots': 0, '_type': 'eighth', 'tuplet_ratio': Fraction(1, 1), 'is_grace_note': True, 'state': <musicXML_parser.mxp.main.MusicXMLParserState object at 0x7fe14d450d30>, 'after_grace_note': True, 'grace_order': -1, 'num_grace': 3}
# {'duration': 0, 'midi_ticks': 0.0, 'seconds': 0.0, 'time_position': 37.4375, 'xml_position': 12000, 'dots': 0, '_type': '16th', 'tuplet_ratio': Fraction(1, 1), 'is_grace_note': True, 'state': <musicXML_parser.mxp.main.MusicXMLParserState object at 0x7fe14d450d30>, 'after_grace_note': True, 'grace_order': -2, 'num_grace': 2}
# {'duration': 0, 'midi_ticks': 0.0, 'seconds': 0.0, 'time_position': 37.46875, 'xml_position': 12000, 'dots': 0, '_type': '16th', 'tuplet_ratio': Fraction(1, 1), 'is_grace_note': True, 'state': <musicXML_parser.mxp.main.MusicXMLParserState object at 0x7fe14d450d30>, 'after_grace_note': True, 'grace_order': -1, 'num_grace': 2}
# {'duration': 0, 'midi_ticks': 0.0, 'seconds': 0.0, 'time_position': 40.4375, 'xml_position': 12960, 'dots': 0, '_type': '16th', 'tuplet_ratio': Fraction(1, 1), 'is_grace_note': True, 'state': <musicXML_parser.mxp.main.MusicXMLParserState object at 0x7fe14d450d30>, 'after_grace_note': True, 'grace_order': -2, 'num_grace': 2}
# {'duration': 0, 'midi_ticks': 0.0, 'seconds': 0.0, 'time_position': 40.46875, 'xml_position': 12960, 'dots': 0, '_type': '16th', 'tuplet_ratio': Fraction(1, 1), 'is_grace_note': True, 'state': <musicXML_parser.mxp.main.MusicXMLParserState object at 0x7fe14d450d30>, 'after_grace_note': True, 'grace_order': -1, 'num_grace': 2}
# {'duration': 0, 'midi_ticks': 0.0, 'seconds': 0.0, 'time_position': 45.25, 'xml_position': 14560, 'dots': 0, '_type': 'eighth', 'tuplet_ratio': Fraction(1, 1), 'is_grace_note': True, 'state': <musicXML_parser.mxp.main.MusicXMLParserState object at 0x7fe14d450d30>, 'after_grace_note': True, 'grace_order': -4, 'num_grace': 4}
# {'duration': 0, 'midi_ticks': 0.0, 'seconds': 0.0, 'time_position': 45.3125, 'xml_position': 14560, 'dots': 0, '_type': 'eighth', 'tuplet_ratio': Fraction(1, 1), 'is_grace_note': True, 'state': <musicXML_parser.mxp.main.MusicXMLParserState object at 0x7fe14d450d30>, 'after_grace_note': True, 'grace_order': -3, 'num_grace': 4}
# {'duration': 0, 'midi_ticks': 0.0, 'seconds': 0.0, 'time_position': 45.375, 'xml_position': 14560, 'dots': 0, '_type': 'eighth', 'tuplet_ratio': Fraction(1, 1), 'is_grace_note': True, 'state': <musicXML_parser.mxp.main.MusicXMLParserState object at 0x7fe14d450d30>, 'after_grace_note': True, 'grace_order': -2, 'num_grace': 4}
# {'duration': 0, 'midi_ticks': 0.0, 'seconds': 0.0, 'time_position': 45.4375, 'xml_position': 14560, 'dots': 0, '_type': 'eighth', 'tuplet_ratio': Fraction(1, 1), 'is_grace_note': True, 'state': <musicXML_parser.mxp.main.MusicXMLParserState object at 0x7fe14d450d30>, 'after_grace_note': True, 'grace_order': -1, 'num_grace': 4}
# {'duration': 0, 'midi_ticks': 0.0, 'seconds': 0.0, 'time_position': 46.75, 'xml_position': 15040, 'dots': 0, '_type': 'eighth', 'tuplet_ratio': Fraction(1, 1), 'is_grace_note': True, 'state': <musicXML_parser.mxp.main.MusicXMLParserState object at 0x7fe14d450d30>, 'after_grace_note': True, 'grace_order': -4, 'num_grace': 4}
# {'duration': 0, 'midi_ticks': 0.0, 'seconds': 0.0, 'time_position': 46.8125, 'xml_position': 15040, 'dots': 0, '_type': 'eighth', 'tuplet_ratio': Fraction(1, 1), 'is_grace_note': True, 'state': <musicXML_parser.mxp.main.MusicXMLParserState object at 0x7fe14d450d30>, 'after_grace_note': True, 'grace_order': -3, 'num_grace': 4}
# {'duration': 0, 'midi_ticks': 0.0, 'seconds': 0.0, 'time_position': 46.875, 'xml_position': 15040, 'dots': 0, '_type': 'eighth', 'tuplet_ratio': Fraction(1, 1), 'is_grace_note': True, 'state': <musicXML_parser.mxp.main.MusicXMLParserState object at 0x7fe14d450d30>, 'after_grace_note': True, 'grace_order': -2, 'num_grace': 4}
# {'duration': 0, 'midi_ticks': 0.0, 'seconds': 0.0, 'time_position': 46.9375, 'xml_position': 15040, 'dots': 0, '_type': 'eighth', 'tuplet_ratio': Fraction(1, 1), 'is_grace_note': True, 'state': <musicXML_parser.mxp.main.MusicXMLParserState object at 0x7fe14d450d30>, 'after_grace_note': True, 'grace_order': -1, 'num_grace': 4}
# {'duration': 0, 'midi_ticks': 0.0, 'seconds': 0.0, 'time_position': 81.6875, 'xml_position': 26160, 'dots': 0, '_type': 'eighth', 'tuplet_ratio': Fraction(1, 1), 'is_grace_note': True, 'state': <musicXML_parser.mxp.main.MusicXMLParserState object at 0x7fe14d450d30>, 'after_grace_note': True, 'grace_order': -1, 'num_grace': 1}
# {'duration': 0, 'midi_ticks': 0.0, 'seconds': 0.0, 'time_position': 84.6875, 'xml_position': 27120, 'dots': 0, '_type': 'eighth', 'tuplet_ratio': Fraction(1, 1), 'is_grace_note': True, 'state': <musicXML_parser.mxp.main.MusicXMLParserState object at 0x7fe14d450d30>, 'after_grace_note': True, 'grace_order': -1, 'num_grace': 1}
# {'duration': 0, 'midi_ticks': 0.0, 'seconds': 0.0, 'time_position': 87.6875, 'xml_position': 28080, 'dots': 0, '_type': 'eighth', 'tuplet_ratio': Fraction(1, 1), 'is_grace_note': True, 'state': <musicXML_parser.mxp.main.MusicXMLParserState object at 0x7fe14d450d30>, 'after_grace_note': True, 'grace_order': -1, 'num_grace': 1}
# {'duration': 0, 'midi_ticks': 0.0, 'seconds': 0.0, 'time_position': 90.6875, 'xml_position': 29040, 'dots': 0, '_type': 'eighth', 'tuplet_ratio': Fraction(1, 1), 'is_grace_note': True, 'state': <musicXML_parser.mxp.main.MusicXMLParserState object at 0x7fe14d450d30>, 'after_grace_note': True, 'grace_order': -1, 'num_grace': 1}
# {'duration': 0, 'midi_ticks': 0.0, 'seconds': 0.0, 'time_position': 92.1875, 'xml_position': 29520, 'dots': 0, '_type': 'eighth', 'tuplet_ratio': Fraction(1, 1), 'is_grace_note': True, 'state': <musicXML_parser.mxp.main.MusicXMLParserState object at 0x7fe14d450d30>, 'after_grace_note': True, 'grace_order': -1, 'num_grace': 1}
# {'duration': 0, 'midi_ticks': 0.0, 'seconds': 0.0, 'time_position': 97.4375, 'xml_position': 31200, 'dots': 0, '_type': 'eighth', 'tuplet_ratio': Fraction(1, 1), 'is_grace_note': True, 'state': <musicXML_parser.mxp.main.MusicXMLParserState object at 0x7fe14d450d30>, 'after_grace_note': True, 'grace_order': -1, 'num_grace': 1}
# {'duration': 0, 'midi_ticks': 0.0, 'seconds': 0.0, 'time_position': 104.1875, 'xml_position': 33360, 'dots': 0, '_type': 'eighth', 'tuplet_ratio': Fraction(1, 1), 'is_grace_note': True, 'state': <musicXML_parser.mxp.main.MusicXMLParserState object at 0x7fe14d450d30>, 'after_grace_note': True, 'grace_order': -1, 'num_grace': 1}
# {'duration': 0, 'midi_ticks': 0.0, 'seconds': 0.0, 'time_position': 110.1875, 'xml_position': 35280, 'dots': 0, '_type': 'eighth', 'tuplet_ratio': Fraction(1, 1), 'is_grace_note': True, 'state': <musicXML_parser.mxp.main.MusicXMLParserState object at 0x7fe14d450d30>, 'after_grace_note': True, 'grace_order': -1, 'num_grace': 1}
# {'duration': 0, 'midi_ticks': 0.0, 'seconds': 0.0, 'time_position': 113.1875, 'xml_position': 36240, 'dots': 0, '_type': 'eighth', 'tuplet_ratio': Fraction(1, 1), 'is_grace_note': True, 'state': <musicXML_parser.mxp.main.MusicXMLParserState object at 0x7fe14d450d30>, 'after_grace_note': True, 'grace_order': -1, 'num_grace': 1}
# {'duration': 0, 'midi_ticks': 0.0, 'seconds': 0.0, 'time_position': 119.9375, 'xml_position': 38400, 'dots': 0, '_type': 'eighth', 'tuplet_ratio': Fraction(1, 1), 'is_grace_note': True, 'state': <musicXML_parser.mxp.main.MusicXMLParserState object at 0x7fe14d450d30>, 'after_grace_note': True, 'grace_order': -1, 'num_grace': 1}
# {'duration': 0, 'midi_ticks': 0.0, 'seconds': 0.0, 'time_position': 121.375, 'xml_position': 38880, 'dots': 0, '_type': 'eighth', 'tuplet_ratio': Fraction(1, 1), 'is_grace_note': True, 'state': <musicXML_parser.mxp.main.MusicXMLParserState object at 0x7fe14d450d30>, 'after_grace_note': True, 'grace_order': -2, 'num_grace': 2}
# {'duration': 0, 'midi_ticks': 0.0, 'seconds': 0.0, 'time_position': 121.4375, 'xml_position': 38880, 'dots': 0, '_type': 'eighth', 'tuplet_ratio': Fraction(1, 1), 'is_grace_note': True, 'state': <musicXML_parser.mxp.main.MusicXMLParserState object at 0x7fe14d450d30>, 'after_grace_note': True, 'grace_order': -1, 'num_grace': 2}
# {'duration': 0, 'midi_ticks': 0.0, 'seconds': 0.0, 'time_position': 128.0625, 'xml_position': 41040, 'dots': 0, '_type': 'eighth', 'tuplet_ratio': Fraction(1, 1), 'is_grace_note': True, 'state': <musicXML_parser.mxp.main.MusicXMLParserState object at 0x7fe14d450d30>, 'after_grace_note': True, 'grace_order': -3, 'num_grace': 3}
# {'duration': 0, 'midi_ticks': 0.0, 'seconds': 0.0, 'time_position': 128.125, 'xml_position': 41040, 'dots': 0, '_type': 'eighth', 'tuplet_ratio': Fraction(1, 1), 'is_grace_note': True, 'state': <musicXML_parser.mxp.main.MusicXMLParserState object at 0x7fe14d450d30>, 'after_grace_note': True, 'grace_order': -2, 'num_grace': 2}
# {'duration': 0, 'midi_ticks': 0.0, 'seconds': 0.0, 'time_position': 128.125, 'xml_position': 41040, 'dots': 0, '_type': 'eighth', 'tuplet_ratio': Fraction(1, 1), 'is_grace_note': True, 'state': <musicXML_parser.mxp.main.MusicXMLParserState object at 0x7fe14d450d30>, 'after_grace_note': True, 'grace_order': -2, 'num_grace': 3}
# {'duration': 0, 'midi_ticks': 0.0, 'seconds': 0.0, 'time_position': 128.1875, 'xml_position': 41040, 'dots': 0, '_type': 'eighth', 'tuplet_ratio': Fraction(1, 1), 'is_grace_note': True, 'state': <musicXML_parser.mxp.main.MusicXMLParserState object at 0x7fe14d450d30>, 'after_grace_note': True, 'grace_order': -1, 'num_grace': 2}
# {'duration': 0, 'midi_ticks': 0.0, 'seconds': 0.0, 'time_position': 128.1875, 'xml_position': 41040, 'dots': 0, '_type': 'eighth', 'tuplet_ratio': Fraction(1, 1), 'is_grace_note': True, 'state': <musicXML_parser.mxp.main.MusicXMLParserState object at 0x7fe14d450d30>, 'after_grace_note': True, 'grace_order': -1, 'num_grace': 3}
# {'duration': 0, 'midi_ticks': 0.0, 'seconds': 0.0, 'time_position': 146.0625, 'xml_position': 46800, 'dots': 0, '_type': 'eighth', 'tuplet_ratio': Fraction(1, 1), 'is_grace_note': True, 'state': <musicXML_parser.mxp.main.MusicXMLParserState object at 0x7fe14d450d30>, 'after_grace_note': True, 'grace_order': -3, 'num_grace': 3}
# {'duration': 0, 'midi_ticks': 0.0, 'seconds': 0.0, 'time_position': 146.125, 'xml_position': 46800, 'dots': 0, '_type': 'eighth', 'tuplet_ratio': Fraction(1, 1), 'is_grace_note': True, 'state': <musicXML_parser.mxp.main.MusicXMLParserState object at 0x7fe14d450d30>, 'after_grace_note': True, 'grace_order': -2, 'num_grace': 3}
# {'duration': 0, 'midi_ticks': 0.0, 'seconds': 0.0, 'time_position': 146.1875, 'xml_position': 46800, 'dots': 0, '_type': 'eighth', 'tuplet_ratio': Fraction(1, 1), 'is_grace_note': True, 'state': <musicXML_parser.mxp.main.MusicXMLParserState object at 0x7fe14d450d30>, 'after_grace_note': True, 'grace_order': -1, 'num_grace': 3}
# {'duration': 0, 'midi_ticks': 0.0, 'seconds': 0.0, 'time_position': 148.4375, 'xml_position': 47520, 'dots': 0, '_type': 'eighth', 'tuplet_ratio': Fraction(1, 1), 'is_grace_note': True, 'state': <musicXML_parser.mxp.main.MusicXMLParserState object at 0x7fe14d450d30>, 'after_grace_note': True, 'grace_order': -1, 'num_grace': 1}
# {'duration': 0, 'midi_ticks': 0.0, 'seconds': 0.0, 'time_position': 149.9375, 'xml_position': 48000, 'dots': 0, '_type': 'eighth', 'tuplet_ratio': Fraction(1, 1), 'is_grace_note': True, 'state': <musicXML_parser.mxp.main.MusicXMLParserState object at 0x7fe14d450d30>, 'after_grace_note': True, 'grace_order': -1, 'num_grace': 1}
# {'duration': 0, 'midi_ticks': 0.0, 'seconds': 0.0, 'time_position': 158.1875, 'xml_position': 50640, 'dots': 0, '_type': 'eighth', 'tuplet_ratio': Fraction(1, 1), 'is_grace_note': True, 'state': <musicXML_parser.mxp.main.MusicXMLParserState object at 0x7fe14d450d30>, 'after_grace_note': True, 'grace_order': -1, 'num_grace': 1}
# {'duration': 0, 'midi_ticks': 0.0, 'seconds': 0.0, 'time_position': 161.1875, 'xml_position': 51600, 'dots': 0, '_type': 'eighth', 'tuplet_ratio': Fraction(1, 1), 'is_grace_note': True, 'state': <musicXML_parser.mxp.main.MusicXMLParserState object at 0x7fe14d450d30>, 'after_grace_note': True, 'grace_order': -1, 'num_grace': 1}
# {'duration': 0, 'midi_ticks': 0.0, 'seconds': 0.0, 'time_position': 164.1875, 'xml_position': 52560, 'dots': 0, '_type': 'eighth', 'tuplet_ratio': Fraction(1, 1), 'is_grace_note': True, 'state': <musicXML_parser.mxp.main.MusicXMLParserState object at 0x7fe14d450d30>, 'after_grace_note': True, 'grace_order': -1, 'num_grace': 1}
# {'duration': 0, 'midi_ticks': 0.0, 'seconds': 0.0, 'time_position': 167.1875, 'xml_position': 53520, 'dots': 0, '_type': 'eighth', 'tuplet_ratio': Fraction(1, 1), 'is_grace_note': True, 'state': <musicXML_parser.mxp.main.MusicXMLParserState object at 0x7fe14d450d30>, 'after_grace_note': True, 'grace_order': -1, 'num_grace': 1}
# {'duration': 0, 'midi_ticks': 0.0, 'seconds': 0.0, 'time_position': 168.6875, 'xml_position': 54000, 'dots': 0, '_type': 'eighth', 'tuplet_ratio': Fraction(1, 1), 'is_grace_note': True, 'state': <musicXML_parser.mxp.main.MusicXMLParserState object at 0x7fe14d450d30>, 'after_grace_note': True, 'grace_order': -1, 'num_grace': 1}
# {'duration': 0, 'midi_ticks': 0.0, 'seconds': 0.0, 'time_position': 172.3125, 'xml_position': 55200, 'dots': 0, '_type': 'eighth', 'tuplet_ratio': Fraction(1, 1), 'is_grace_note': True, 'state': <musicXML_parser.mxp.main.MusicXMLParserState object at 0x7fe14d450d30>, 'after_grace_note': True, 'grace_order': -3, 'num_grace': 3}
# {'duration': 0, 'midi_ticks': 0.0, 'seconds': 0.0, 'time_position': 172.375, 'xml_position': 55200, 'dots': 0, '_type': 'eighth', 'tuplet_ratio': Fraction(1, 1), 'is_grace_note': True, 'state': <musicXML_parser.mxp.main.MusicXMLParserState object at 0x7fe14d450d30>, 'after_grace_note': True, 'grace_order': -2, 'num_grace': 3}
# {'duration': 0, 'midi_ticks': 0.0, 'seconds': 0.0, 'time_position': 172.4375, 'xml_position': 55200, 'dots': 0, '_type': 'eighth', 'tuplet_ratio': Fraction(1, 1), 'is_grace_note': True, 'state': <musicXML_parser.mxp.main.MusicXMLParserState object at 0x7fe14d450d30>, 'after_grace_note': True, 'grace_order': -1, 'num_grace': 3}
# {'duration': 0, 'midi_ticks': 0.0, 'seconds': 0.0, 'time_position': 174.625, 'xml_position': 56160, 'dots': 0, '_type': 'eighth', 'tuplet_ratio': Fraction(1, 1), 'is_grace_note': True, 'state': <musicXML_parser.mxp.main.MusicXMLParserState object at 0x7fe14d450d30>, 'after_grace_note': True, 'grace_order': -14, 'num_grace': 14}
# {'duration': 0, 'midi_ticks': 0.0, 'seconds': 0.0, 'time_position': 174.6875, 'xml_position': 56160, 'dots': 0, '_type': 'eighth', 'tuplet_ratio': Fraction(1, 1), 'is_grace_note': True, 'state': <musicXML_parser.mxp.main.MusicXMLParserState object at 0x7fe14d450d30>, 'after_grace_note': True, 'grace_order': -13, 'num_grace': 14}
# {'duration': 0, 'midi_ticks': 0.0, 'seconds': 0.0, 'time_position': 174.75, 'xml_position': 56160, 'dots': 0, '_type': 'eighth', 'tuplet_ratio': Fraction(1, 1), 'is_grace_note': True, 'state': <musicXML_parser.mxp.main.MusicXMLParserState object at 0x7fe14d450d30>, 'after_grace_note': True, 'grace_order': -12, 'num_grace': 14}
# {'duration': 0, 'midi_ticks': 0.0, 'seconds': 0.0, 'time_position': 174.8125, 'xml_position': 56160, 'dots': 0, '_type': 'eighth', 'tuplet_ratio': Fraction(1, 1), 'is_grace_note': True, 'state': <musicXML_parser.mxp.main.MusicXMLParserState object at 0x7fe14d450d30>, 'after_grace_note': True, 'grace_order': -11, 'num_grace': 14}
# {'duration': 0, 'midi_ticks': 0.0, 'seconds': 0.0, 'time_position': 174.875, 'xml_position': 56160, 'dots': 0, '_type': 'eighth', 'tuplet_ratio': Fraction(1, 1), 'is_grace_note': True, 'state': <musicXML_parser.mxp.main.MusicXMLParserState object at 0x7fe14d450d30>, 'after_grace_note': True, 'grace_order': -10, 'num_grace': 14}
# {'duration': 0, 'midi_ticks': 0.0, 'seconds': 0.0, 'time_position': 174.9375, 'xml_position': 56160, 'dots': 0, '_type': 'eighth', 'tuplet_ratio': Fraction(1, 1), 'is_grace_note': True, 'state': <musicXML_parser.mxp.main.MusicXMLParserState object at 0x7fe14d450d30>, 'after_grace_note': True, 'grace_order': -9, 'num_grace': 14}
# {'duration': 0, 'midi_ticks': 0.0, 'seconds': 0.0, 'time_position': 175.0, 'xml_position': 56160, 'dots': 0, '_type': 'eighth', 'tuplet_ratio': Fraction(1, 1), 'is_grace_note': True, 'state': <musicXML_parser.mxp.main.MusicXMLParserState object at 0x7fe14d450d30>, 'after_grace_note': True, 'grace_order': -8, 'num_grace': 14}
# {'duration': 0, 'midi_ticks': 0.0, 'seconds': 0.0, 'time_position': 175.0625, 'xml_position': 56160, 'dots': 0, '_type': 'eighth', 'tuplet_ratio': Fraction(1, 1), 'is_grace_note': True, 'state': <musicXML_parser.mxp.main.MusicXMLParserState object at 0x7fe14d450d30>, 'after_grace_note': True, 'grace_order': -7, 'num_grace': 14}
# {'duration': 0, 'midi_ticks': 0.0, 'seconds': 0.0, 'time_position': 175.125, 'xml_position': 56160, 'dots': 0, '_type': 'eighth', 'tuplet_ratio': Fraction(1, 1), 'is_grace_note': True, 'state': <musicXML_parser.mxp.main.MusicXMLParserState object at 0x7fe14d450d30>, 'after_grace_note': True, 'grace_order': -6, 'num_grace': 14}
# {'duration': 0, 'midi_ticks': 0.0, 'seconds': 0.0, 'time_position': 175.1875, 'xml_position': 56160, 'dots': 0, '_type': 'eighth', 'tuplet_ratio': Fraction(1, 1), 'is_grace_note': True, 'state': <musicXML_parser.mxp.main.MusicXMLParserState object at 0x7fe14d450d30>, 'after_grace_note': True, 'grace_order': -5, 'num_grace': 14}
# {'duration': 0, 'midi_ticks': 0.0, 'seconds': 0.0, 'time_position': 175.25, 'xml_position': 56160, 'dots': 0, '_type': 'eighth', 'tuplet_ratio': Fraction(1, 1), 'is_grace_note': True, 'state': <musicXML_parser.mxp.main.MusicXMLParserState object at 0x7fe14d450d30>, 'after_grace_note': True, 'grace_order': -4, 'num_grace': 14}
# {'duration': 0, 'midi_ticks': 0.0, 'seconds': 0.0, 'time_position': 175.3125, 'xml_position': 56160, 'dots': 0, '_type': 'eighth', 'tuplet_ratio': Fraction(1, 1), 'is_grace_note': True, 'state': <musicXML_parser.mxp.main.MusicXMLParserState object at 0x7fe14d450d30>, 'after_grace_note': True, 'grace_order': -3, 'num_grace': 14}
# {'duration': 0, 'midi_ticks': 0.0, 'seconds': 0.0, 'time_position': 175.375, 'xml_position': 56160, 'dots': 0, '_type': 'eighth', 'tuplet_ratio': Fraction(1, 1), 'is_grace_note': True, 'state': <musicXML_parser.mxp.main.MusicXMLParserState object at 0x7fe14d450d30>, 'after_grace_note': True, 'grace_order': -2, 'num_grace': 14}
# {'duration': 0, 'midi_ticks': 0.0, 'seconds': 0.0, 'time_position': 175.4375, 'xml_position': 56160, 'dots': 0, '_type': 'eighth', 'tuplet_ratio': Fraction(1, 1), 'is_grace_note': True, 'state': <musicXML_parser.mxp.main.MusicXMLParserState object at 0x7fe14d450d30>, 'after_grace_note': True, 'grace_order': -1, 'num_grace': 14}
# {'duration': 0, 'midi_ticks': 0.0, 'seconds': 0.0, 'time_position': 178.375, 'xml_position': 57120, 'dots': 0, '_type': 'eighth', 'tuplet_ratio': Fraction(1, 1), 'is_grace_note': True, 'state': <musicXML_parser.mxp.main.MusicXMLParserState object at 0x7fe14d450d30>, 'after_grace_note': True, 'grace_order': -2, 'num_grace': 2}
# {'duration': 0, 'midi_ticks': 0.0, 'seconds': 0.0, 'time_position': 178.4375, 'xml_position': 57120, 'dots': 0, '_type': 'eighth', 'tuplet_ratio': Fraction(1, 1), 'is_grace_note': True, 'state': <musicXML_parser.mxp.main.MusicXMLParserState object at 0x7fe14d450d30>, 'after_grace_note': True, 'grace_order': -1, 'num_grace': 2}
# {'duration': 0, 'midi_ticks': 0.0, 'seconds': 0.0, 'time_position': 180.625, 'xml_position': 58080, 'dots': 0, '_type': 'eighth', 'tuplet_ratio': Fraction(1, 1), 'is_grace_note': True, 'state': <musicXML_parser.mxp.main.MusicXMLParserState object at 0x7fe14d450d30>, 'after_grace_note': True, 'grace_order': -14, 'num_grace': 14}
# {'duration': 0, 'midi_ticks': 0.0, 'seconds': 0.0, 'time_position': 180.6875, 'xml_position': 58080, 'dots': 0, '_type': 'eighth', 'tuplet_ratio': Fraction(1, 1), 'is_grace_note': True, 'state': <musicXML_parser.mxp.main.MusicXMLParserState object at 0x7fe14d450d30>, 'after_grace_note': True, 'grace_order': -13, 'num_grace': 14}
# {'duration': 0, 'midi_ticks': 0.0, 'seconds': 0.0, 'time_position': 180.75, 'xml_position': 58080, 'dots': 0, '_type': 'eighth', 'tuplet_ratio': Fraction(1, 1), 'is_grace_note': True, 'state': <musicXML_parser.mxp.main.MusicXMLParserState object at 0x7fe14d450d30>, 'after_grace_note': True, 'grace_order': -12, 'num_grace': 14}
# {'duration': 0, 'midi_ticks': 0.0, 'seconds': 0.0, 'time_position': 180.8125, 'xml_position': 58080, 'dots': 0, '_type': 'eighth', 'tuplet_ratio': Fraction(1, 1), 'is_grace_note': True, 'state': <musicXML_parser.mxp.main.MusicXMLParserState object at 0x7fe14d450d30>, 'after_grace_note': True, 'grace_order': -11, 'num_grace': 14}
# {'duration': 0, 'midi_ticks': 0.0, 'seconds': 0.0, 'time_position': 180.875, 'xml_position': 58080, 'dots': 0, '_type': 'eighth', 'tuplet_ratio': Fraction(1, 1), 'is_grace_note': True, 'state': <musicXML_parser.mxp.main.MusicXMLParserState object at 0x7fe14d450d30>, 'after_grace_note': True, 'grace_order': -10, 'num_grace': 14}
# {'duration': 0, 'midi_ticks': 0.0, 'seconds': 0.0, 'time_position': 180.9375, 'xml_position': 58080, 'dots': 0, '_type': 'eighth', 'tuplet_ratio': Fraction(1, 1), 'is_grace_note': True, 'state': <musicXML_parser.mxp.main.MusicXMLParserState object at 0x7fe14d450d30>, 'after_grace_note': True, 'grace_order': -9, 'num_grace': 14}
# {'duration': 0, 'midi_ticks': 0.0, 'seconds': 0.0, 'time_position': 181.0, 'xml_position': 58080, 'dots': 0, '_type': 'eighth', 'tuplet_ratio': Fraction(1, 1), 'is_grace_note': True, 'state': <musicXML_parser.mxp.main.MusicXMLParserState object at 0x7fe14d450d30>, 'after_grace_note': True, 'grace_order': -8, 'num_grace': 14}
# {'duration': 0, 'midi_ticks': 0.0, 'seconds': 0.0, 'time_position': 181.0625, 'xml_position': 58080, 'dots': 0, '_type': 'eighth', 'tuplet_ratio': Fraction(1, 1), 'is_grace_note': True, 'state': <musicXML_parser.mxp.main.MusicXMLParserState object at 0x7fe14d450d30>, 'after_grace_note': True, 'grace_order': -7, 'num_grace': 14}
# {'duration': 0, 'midi_ticks': 0.0, 'seconds': 0.0, 'time_position': 181.125, 'xml_position': 58080, 'dots': 0, '_type': 'eighth', 'tuplet_ratio': Fraction(1, 1), 'is_grace_note': True, 'state': <musicXML_parser.mxp.main.MusicXMLParserState object at 0x7fe14d450d30>, 'after_grace_note': True, 'grace_order': -6, 'num_grace': 14}
# {'duration': 0, 'midi_ticks': 0.0, 'seconds': 0.0, 'time_position': 181.1875, 'xml_position': 58080, 'dots': 0, '_type': 'eighth', 'tuplet_ratio': Fraction(1, 1), 'is_grace_note': True, 'state': <musicXML_parser.mxp.main.MusicXMLParserState object at 0x7fe14d450d30>, 'after_grace_note': True, 'grace_order': -5, 'num_grace': 14}
# {'duration': 0, 'midi_ticks': 0.0, 'seconds': 0.0, 'time_position': 181.25, 'xml_position': 58080, 'dots': 0, '_type': 'eighth', 'tuplet_ratio': Fraction(1, 1), 'is_grace_note': True, 'state': <musicXML_parser.mxp.main.MusicXMLParserState object at 0x7fe14d450d30>, 'after_grace_note': True, 'grace_order': -4, 'num_grace': 14}
# {'duration': 0, 'midi_ticks': 0.0, 'seconds': 0.0, 'time_position': 181.3125, 'xml_position': 58080, 'dots': 0, '_type': 'eighth', 'tuplet_ratio': Fraction(1, 1), 'is_grace_note': True, 'state': <musicXML_parser.mxp.main.MusicXMLParserState object at 0x7fe14d450d30>, 'after_grace_note': True, 'grace_order': -3, 'num_grace': 14}
# {'duration': 0, 'midi_ticks': 0.0, 'seconds': 0.0, 'time_position': 181.375, 'xml_position': 58080, 'dots': 0, '_type': 'eighth', 'tuplet_ratio': Fraction(1, 1), 'is_grace_note': True, 'state': <musicXML_parser.mxp.main.MusicXMLParserState object at 0x7fe14d450d30>, 'after_grace_note': True, 'grace_order': -2, 'num_grace': 14}
# {'duration': 0, 'midi_ticks': 0.0, 'seconds': 0.0, 'time_position': 181.4375, 'xml_position': 58080, 'dots': 0, '_type': 'eighth', 'tuplet_ratio': Fraction(1, 1), 'is_grace_note': True, 'state': <musicXML_parser.mxp.main.MusicXMLParserState object at 0x7fe14d450d30>, 'after_grace_note': True, 'grace_order': -1, 'num_grace': 14}
# {'duration': 0, 'midi_ticks': 0.0, 'seconds': 0.0, 'time_position': 200.1875, 'xml_position': 64080, 'dots': 0, '_type': '16th', 'tuplet_ratio': Fraction(1, 1), 'is_grace_note': True, 'state': <musicXML_parser.mxp.main.MusicXMLParserState object at 0x7fe14d450d30>, 'after_grace_note': True, 'grace_order': -2, 'num_grace': 2}
# {'duration': 0, 'midi_ticks': 0.0, 'seconds': 0.0, 'time_position': 200.21875, 'xml_position': 64080, 'dots': 0, '_type': '16th', 'tuplet_ratio': Fraction(1, 1), 'is_grace_note': True, 'state': <musicXML_parser.mxp.main.MusicXMLParserState object at 0x7fe14d450d30>, 'after_grace_note': True, 'grace_order': -1, 'num_grace': 2}
# {'duration': 0, 'midi_ticks': 0.0, 'seconds': 0.0, 'time_position': 200.9375, 'xml_position': 64320, 'dots': 0, '_type': '16th', 'tuplet_ratio': Fraction(1, 1), 'is_grace_note': True, 'state': <musicXML_parser.mxp.main.MusicXMLParserState object at 0x7fe14d450d30>, 'after_grace_note': True, 'grace_order': -2, 'num_grace': 2}
# {'duration': 0, 'midi_ticks': 0.0, 'seconds': 0.0, 'time_position': 200.96875, 'xml_position': 64320, 'dots': 0, '_type': '16th', 'tuplet_ratio': Fraction(1, 1), 'is_grace_note': True, 'state': <musicXML_parser.mxp.main.MusicXMLParserState object at 0x7fe14d450d30>, 'after_grace_note': True, 'grace_order': -1, 'num_grace': 2}
# {'duration': 0, 'midi_ticks': 0.0, 'seconds': 0.0, 'time_position': 201.6875, 'xml_position': 64560, 'dots': 0, '_type': '16th', 'tuplet_ratio': Fraction(1, 1), 'is_grace_note': True, 'state': <musicXML_parser.mxp.main.MusicXMLParserState object at 0x7fe14d450d30>, 'after_grace_note': True, 'grace_order': -2, 'num_grace': 2}
# {'duration': 0, 'midi_ticks': 0.0, 'seconds': 0.0, 'time_position': 201.71875, 'xml_position': 64560, 'dots': 0, '_type': '16th', 'tuplet_ratio': Fraction(1, 1), 'is_grace_note': True, 'state': <musicXML_parser.mxp.main.MusicXMLParserState object at 0x7fe14d450d30>, 'after_grace_note': True, 'grace_order': -1, 'num_grace': 2}
# {'duration': 0, 'midi_ticks': 0.0, 'seconds': 0.0, 'time_position': 202.4375, 'xml_position': 64800, 'dots': 0, '_type': 'eighth', 'tuplet_ratio': Fraction(1, 1), 'is_grace_note': True, 'state': <musicXML_parser.mxp.main.MusicXMLParserState object at 0x7fe14d450d30>, 'after_grace_note': True, 'grace_order': -1, 'num_grace': 1}
# {'duration': 0, 'midi_ticks': 0.0, 'seconds': 0.0, 'time_position': 206.9375, 'xml_position': 66240, 'dots': 0, '_type': 'eighth', 'tuplet_ratio': Fraction(1, 1), 'is_grace_note': True, 'state': <musicXML_parser.mxp.main.MusicXMLParserState object at 0x7fe14d450d30>, 'after_grace_note': True, 'grace_order': -1, 'num_grace': 1}
# {'duration': 0, 'midi_ticks': 0.0, 'seconds': 0.0, 'time_position': 212.9375, 'xml_position': 68160, 'dots': 0, '_type': 'eighth', 'tuplet_ratio': Fraction(1, 1), 'is_grace_note': True, 'state': <musicXML_parser.mxp.main.MusicXMLParserState object at 0x7fe14d450d30>, 'after_grace_note': True, 'grace_order': -1, 'num_grace': 1}
# {'duration': 0, 'midi_ticks': 0.0, 'seconds': 0.0, 'time_position': 219.6875, 'xml_position': 70320, 'dots': 0, '_type': 'eighth', 'tuplet_ratio': Fraction(1, 1), 'is_grace_note': True, 'state': <musicXML_parser.mxp.main.MusicXMLParserState object at 0x7fe14d450d30>, 'after_grace_note': True, 'grace_order': -1, 'num_grace': 1}
# {'duration': 0, 'midi_ticks': 0.0, 'seconds': 0.0, 'time_position': 222.6875, 'xml_position': 71280, 'dots': 0, '_type': 'eighth', 'tuplet_ratio': Fraction(1, 1), 'is_grace_note': True, 'state': <musicXML_parser.mxp.main.MusicXMLParserState object at 0x7fe14d450d30>, 'after_grace_note': True, 'grace_order': -1, 'num_grace': 1}
# {'duration': 0, 'midi_ticks': 0.0, 'seconds': 0.0, 'time_position': 225.6875, 'xml_position': 72240, 'dots': 0, '_type': 'eighth', 'tuplet_ratio': Fraction(1, 1), 'is_grace_note': True, 'state': <musicXML_parser.mxp.main.MusicXMLParserState object at 0x7fe14d450d30>, 'after_grace_note': True, 'grace_order': -1, 'num_grace': 1}
# {'duration': 0, 'midi_ticks': 0.0, 'seconds': 0.0, 'time_position': 228.6875, 'xml_position': 73200, 'dots': 0, '_type': 'eighth', 'tuplet_ratio': Fraction(1, 1), 'is_grace_note': True, 'state': <musicXML_parser.mxp.main.MusicXMLParserState object at 0x7fe14d450d30>, 'after_grace_note': True, 'grace_order': -1, 'num_grace': 1}
# {'duration': 0, 'midi_ticks': 0.0, 'seconds': 0.0, 'time_position': 230.1875, 'xml_position': 73680, 'dots': 0, '_type': 'eighth', 'tuplet_ratio': Fraction(1, 1), 'is_grace_note': True, 'state': <musicXML_parser.mxp.main.MusicXMLParserState object at 0x7fe14d450d30>, 'after_grace_note': True, 'grace_order': -1, 'num_grace': 1}
# {'duration': 0, 'midi_ticks': 0.0, 'seconds': 0.0, 'time_position': 284.1875, 'xml_position': 90960, 'dots': 0, '_type': 'eighth', 'tuplet_ratio': Fraction(1, 1), 'is_grace_note': True, 'state': <musicXML_parser.mxp.main.MusicXMLParserState object at 0x7fe14d450d30>, 'after_grace_note': True, 'grace_order': -1, 'num_grace': 1}
# {'duration': 0, 'midi_ticks': 0.0, 'seconds': 0.0, 'time_position': 290.1875, 'xml_position': 92880, 'dots': 0, '_type': 'eighth', 'tuplet_ratio': Fraction(1, 1), 'is_grace_note': True, 'state': <musicXML_parser.mxp.main.MusicXMLParserState object at 0x7fe14d450d30>, 'after_grace_note': True, 'grace_order': -1, 'num_grace': 1}
# {'duration': 0, 'midi_ticks': 0.0, 'seconds': 0.0, 'time_position': 296.1875, 'xml_position': 94800, 'dots': 0, '_type': 'eighth', 'tuplet_ratio': Fraction(1, 1), 'is_grace_note': True, 'state': <musicXML_parser.mxp.main.MusicXMLParserState object at 0x7fe14d450d30>, 'after_grace_note': True, 'grace_order': -1, 'num_grace': 1}
# {'duration': 0, 'midi_ticks': 0.0, 'seconds': 0.0, 'time_position': 302.1875, 'xml_position': 96720, 'dots': 0, '_type': 'eighth', 'tuplet_ratio': Fraction(1, 1), 'is_grace_note': True, 'state': <musicXML_parser.mxp.main.MusicXMLParserState object at 0x7fe14d450d30>, 'after_grace_note': True, 'grace_order': -1, 'num_grace': 1}
# {'duration': 0, 'midi_ticks': 0.0, 'seconds': 0.0, 'time_position': 308.1875, 'xml_position': 98640, 'dots': 0, '_type': 'eighth', 'tuplet_ratio': Fraction(1, 1), 'is_grace_note': True, 'state': <musicXML_parser.mxp.main.MusicXMLParserState object at 0x7fe14d450d30>, 'after_grace_note': True, 'grace_order': -1, 'num_grace': 1}
# {'duration': 0, 'midi_ticks': 0.0, 'seconds': 0.0, 'time_position': 321.6875, 'xml_position': 102960, 'dots': 0, '_type': 'eighth', 'tuplet_ratio': Fraction(1, 1), 'is_grace_note': True, 'state': <musicXML_parser.mxp.main.MusicXMLParserState object at 0x7fe14d450d30>, 'after_grace_note': True, 'grace_order': -1, 'num_grace': 1}
# {'duration': 0, 'midi_ticks': 0.0, 'seconds': 0.0, 'time_position': 327.6875, 'xml_position': 104880, 'dots': 0, '_type': 'eighth', 'tuplet_ratio': Fraction(1, 1), 'is_grace_note': True, 'state': <musicXML_parser.mxp.main.MusicXMLParserState object at 0x7fe14d450d30>, 'after_grace_note': True, 'grace_order': -1, 'num_grace': 1}
# {'duration': 0, 'midi_ticks': 0.0, 'seconds': 0.0, 'time_position': 330.6875, 'xml_position': 105840, 'dots': 0, '_type': 'eighth', 'tuplet_ratio': Fraction(1, 1), 'is_grace_note': True, 'state': <musicXML_parser.mxp.main.MusicXMLParserState object at 0x7fe14d450d30>, 'after_grace_note': True, 'grace_order': -1, 'num_grace': 1}
# {'duration': 0, 'midi_ticks': 0.0, 'seconds': 0.0, 'time_position': 344.75, 'xml_position': 110400, 'dots': 0, '_type': 'eighth', 'tuplet_ratio': Fraction(1, 1), 'is_grace_note': True, 'state': <musicXML_parser.mxp.main.MusicXMLParserState object at 0x7fe14d450d30>, 'after_grace_note': True, 'grace_order': -4, 'num_grace': 4}
# {'duration': 0, 'midi_ticks': 0.0, 'seconds': 0.0, 'time_position': 344.8125, 'xml_position': 110400, 'dots': 0, '_type': 'eighth', 'tuplet_ratio': Fraction(1, 1), 'is_grace_note': True, 'state': <musicXML_parser.mxp.main.MusicXMLParserState object at 0x7fe14d450d30>, 'after_grace_note': True, 'grace_order': -3, 'num_grace': 4}
# {'duration': 0, 'midi_ticks': 0.0, 'seconds': 0.0, 'time_position': 344.875, 'xml_position': 110400, 'dots': 0, '_type': 'eighth', 'tuplet_ratio': Fraction(1, 1), 'is_grace_note': True, 'state': <musicXML_parser.mxp.main.MusicXMLParserState object at 0x7fe14d450d30>, 'after_grace_note': True, 'grace_order': -2, 'num_grace': 4}
# {'duration': 0, 'midi_ticks': 0.0, 'seconds': 0.0, 'time_position': 344.9375, 'xml_position': 110400, 'dots': 0, '_type': 'eighth', 'tuplet_ratio': Fraction(1, 1), 'is_grace_note': True, 'state': <musicXML_parser.mxp.main.MusicXMLParserState object at 0x7fe14d450d30>, 'after_grace_note': True, 'grace_order': -1, 'num_grace': 4}
# {'duration': 0, 'midi_ticks': 0.0, 'seconds': 0.0, 'time_position': 347.75, 'xml_position': 111360, 'dots': 0, '_type': 'eighth', 'tuplet_ratio': Fraction(1, 1), 'is_grace_note': True, 'state': <musicXML_parser.mxp.main.MusicXMLParserState object at 0x7fe14d450d30>, 'after_grace_note': True, 'grace_order': -4, 'num_grace': 4}
# {'duration': 0, 'midi_ticks': 0.0, 'seconds': 0.0, 'time_position': 347.8125, 'xml_position': 111360, 'dots': 0, '_type': 'eighth', 'tuplet_ratio': Fraction(1, 1), 'is_grace_note': True, 'state': <musicXML_parser.mxp.main.MusicXMLParserState object at 0x7fe14d450d30>, 'after_grace_note': True, 'grace_order': -3, 'num_grace': 4}
# {'duration': 0, 'midi_ticks': 0.0, 'seconds': 0.0, 'time_position': 347.875, 'xml_position': 111360, 'dots': 0, '_type': 'eighth', 'tuplet_ratio': Fraction(1, 1), 'is_grace_note': True, 'state': <musicXML_parser.mxp.main.MusicXMLParserState object at 0x7fe14d450d30>, 'after_grace_note': True, 'grace_order': -2, 'num_grace': 4}
# {'duration': 0, 'midi_ticks': 0.0, 'seconds': 0.0, 'time_position': 347.9375, 'xml_position': 111360, 'dots': 0, '_type': 'eighth', 'tuplet_ratio': Fraction(1, 1), 'is_grace_note': True, 'state': <musicXML_parser.mxp.main.MusicXMLParserState object at 0x7fe14d450d30>, 'after_grace_note': True, 'grace_order': -1, 'num_grace': 4}
# {'duration': 0, 'midi_ticks': 0.0, 'seconds': 0.0, 'time_position': 351.625, 'xml_position': 112560, 'dots': 0, '_type': 'eighth', 'tuplet_ratio': Fraction(1, 1), 'is_grace_note': True, 'state': <musicXML_parser.mxp.main.MusicXMLParserState object at 0x7fe14d450d30>, 'after_grace_note': True, 'grace_order': -2, 'num_grace': 2}
# {'duration': 0, 'midi_ticks': 0.0, 'seconds': 0.0, 'time_position': 351.6875, 'xml_position': 112560, 'dots': 0, '_type': 'eighth', 'tuplet_ratio': Fraction(1, 1), 'is_grace_note': True, 'state': <musicXML_parser.mxp.main.MusicXMLParserState object at 0x7fe14d450d30>, 'after_grace_note': True, 'grace_order': -1, 'num_grace': 2}
# {'duration': 0, 'midi_ticks': 0.0, 'seconds': 0.0, 'time_position': 353.125, 'xml_position': 113040, 'dots': 0, '_type': 'eighth', 'tuplet_ratio': Fraction(1, 1), 'is_grace_note': True, 'state': <musicXML_parser.mxp.main.MusicXMLParserState object at 0x7fe14d450d30>, 'after_grace_note': True, 'grace_order': -2, 'num_grace': 2}
# {'duration': 0, 'midi_ticks': 0.0, 'seconds': 0.0, 'time_position': 353.1875, 'xml_position': 113040, 'dots': 0, '_type': 'eighth', 'tuplet_ratio': Fraction(1, 1), 'is_grace_note': True, 'state': <musicXML_parser.mxp.main.MusicXMLParserState object at 0x7fe14d450d30>, 'after_grace_note': True, 'grace_order': -1, 'num_grace': 2}
